# %% [markdown]
# <a href="https://colab.research.google.com/github/VikoFirdausi/IpynbFiles/blob/main/Reduce_Video_Resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount Google Drive**
# ---

# %%
#@title Mount GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# !apt install mediainfo

# %% [markdown]
# # **File Directory**
# ---

# %%
#@title View File List
# !ls

# %%
 Directory = '' #@param {type: "string"}
# !cd "{Directory}"

# %% [markdown]
# # **Video Information**

# %%
File_Video_name = '' #@param {type: "string"}
# !mediainfo --fullscan {File_Video_name}

# %% [markdown]
#  # **Reduce Video Resolution**

# %%
 
Input_Video = '' #@param {type: "string"}
Resolution = '640x480' #@param ["640x480", "1280x720", "1920x1080"]
Output_Video = '' #@param {type: "string"}
# !ffmpeg -i {Input_Video} -r 30 -s {Resolution} {Output_Video}
