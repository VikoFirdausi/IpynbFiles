# %% [markdown]
# <a href="https://colab.research.google.com/github/VikoFirdausi/IpynbFiles/blob/main/Ziping_and_Copying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Mount GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# !apt install ncdu
# %cd /content/gdrive/MyDrive

# %%
# !ls

# %%
Directory = '' #@param {type:"string"}
# %cd "{Directory}"

# %% [markdown]
# # **See List contents of archive**

# %%
Name_Archive = '' #@param{type:"string"}
!7z l "{Name_Archive}"

# %% [markdown]
# # **Zipping File**

# %%
File_Name = '' #@param {type:"string"}
Source_File = '' #@param {type:"string"}
# %cd {Source_File}
!7z a {File_Name}.7z
# %cd /content/gdrive/MyDrive/Copy

# %% [markdown]
# # **Extrack File**

# %%
Name_file = '' #@param{type:"string"}
Password = '' #@param{type:"string"}
Directory = '' #@param{type:"string"}
!7z x -p"{Password}" "{Name_file}" -o"{Directory}"

# %% [markdown]
# # **Copy File**

# %%
Directory = '' #@param {type:"string"}
# %cd "{Directory}"
# Out:
# /root

# %%
# !ls

# %%
Directory1 = '' #@param {type: "string"}
Destination = '' #@param {type: "string"}
# !cp -r -v "{Directory1}" "{Destination}"

# %% [markdown]
# # **Check Size Directory**

# %%
Directory2 = '' #@param {type:"string"}
# %cd "{Directory2}"

# %%
# !ncdu
